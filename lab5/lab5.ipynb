# %%
from Sum import read, Union
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
im_path = 'data\\image_0{}.png'
mask_path = 'data\\mask_0{}.png'

# %%
im, m = read(im_path, mask_path)

# %%
for idx in range(5):
    plt.figure()
    plt.subplot(121)
    plt.imshow(im[idx])
    plt.subplot(122)
    plt.imshow(m[idx], cmap='gray')

# %%
u = Union(im, m, 255)
res = u.merge()
plt.imshow(res)
